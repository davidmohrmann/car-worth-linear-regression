# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model

# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline

# %%
cars = pd.read_csv("car_data.csv")

# %% [markdown]
# # Task 1
# 1. Find the linear regression equation for mileage vs price.
# 2. Chart the original data and the equation on the chart.
# 3. Find the equation's R2 score (use the .score method) to determine whether the equation is a good fit for this data. (0.8 and greater is considered a strong correlation.)

# %%
cars.head()
# Out:
#           Price  Mileage   Make    Model      Trim   Type  Cylinder  Liter  \
# 0  17314.103129     8221  Buick  Century  Sedan 4D  Sedan         6    3.1
# 1  17542.036083     9135  Buick  Century  Sedan 4D  Sedan         6    3.1
# 2  16218.847862    13196  Buick  Century  Sedan 4D  Sedan         6    3.1
# 3  16336.913140    16342  Buick  Century  Sedan 4D  Sedan         6    3.1
# 4  16339.170324    19832  Buick  Century  Sedan 4D  Sedan         6    3.1
#
#    Doors  Cruise  Sound  Leather
# 0      4       1      1        1
# 1      4       1      1        0
# 2      4       1      1        0
# 3      4       1      0        0
# 4      4       1      0        1

# %%
# visualize the relationship between the features(Mileage) and the response (Price) using scatterplots
cars.plot(kind='scatter', x='Mileage', y='Price')

# %% [markdown]
# # Linear Regression

# %%
# pull out the x and y from our data

# input data expects x values on their own separate rows
# use double brackets to keep data in a DataFrame, which meets that requirement
input_data = cars[['Mileage']]
output_data = cars['Price']

# %%
regression = linear_model.LinearRegression()
regression.fit(input_data, output_data)

print(regression.coef_, regression.intercept_)
print(regression.score(input_data, output_data))
# Out:
# [-0.1725205] 24764.5590061
# 0.0204634473235

# %% [markdown]
# Mileage and Price
#
# Coefficient = -0.1725205
# Intercept = 24764.5590061
# r^2 = 0.0204634473235

# %% [markdown]
# # Linear Regression Score
# The score of mileage and price is 0.0204634473235. This low correlation shows there is not much influence on the price of a vehicle based on the vehicle's mileage.

# %% [markdown]
# # Linear Regression Plot

# %%
plt.scatter(input_data, output_data)
plt.plot(input_data, regression.predict(input_data), color='red', linewidth=3)

# %% [markdown]
# # Task 2
# 1. Use mileage, cylinders, liters, doors, cruise, sound, and leather to find the linear regression equation.
# 2. Find the equation's R2 score (use the .score method) to determine whether the equation is a good fit for this data. (0.8 and greater is considered a strong correlation.)
# 3. Find the combination of the factors that is the best predictor for price.

# %% [markdown]
# # Regression Equation (multiple inputs)

# %%
# pull out the x and y from our data

# input data expects x values on their own separate rows
# use double brackets to keep data in a DataFrame, which meets that requirement
input_data = cars[['Mileage', 'Cylinder', 'Liter', 'Cruise', 'Doors', 'Leather', 'Sound']]
output_data = cars['Price']

# %%
# using all of the inputs, determine the coefficient and score for the relationship. The score will relate the r^2 of
# the inputs and price. 
regression = linear_model.LinearRegression()
regression.fit(input_data, output_data)

print(regression.coef_, regression.intercept_)
print(regression.score(input_data, output_data))
# Out:
# [ 4054.20250438] -17.0574870742
# 0.323859037595

# %% [markdown]
# # Regression Equation per Individual inputs (collective input from above)

# %%
input_data = cars[['Mileage']]
output_data = cars['Price']
regression1 = linear_model.LinearRegression()
regression1.fit(input_data, output_data)

print(regression1.coef_, regression1.intercept_)
print(regression1.score(input_data, output_data))
# Out:
# [-0.1725205] 24764.5590061
# 0.0204634473235

# %%
plt.scatter(input_data, output_data)
plt.plot(input_data, regression1.predict(input_data), color='red', linewidth=3)

# %%
input_data = cars[['Cylinder']]
output_data = cars['Price']
regression2 = linear_model.LinearRegression()
regression2.fit(input_data, output_data)

print(regression2.coef_, regression2.intercept_)
print(regression2.score(input_data, output_data))
# Out:
# [ 4054.20250438] -17.0574870742
# 0.323859037595

# %%
plt.scatter(input_data, output_data)
plt.plot(input_data, regression2.predict(input_data), color='red', linewidth=3)

# %%
input_data = cars[['Liter']]
output_data = cars['Price']
regression3 = linear_model.LinearRegression()
regression3.fit(input_data, output_data)

print(regression3.coef_, regression3.intercept_)
print(regression3.score(input_data, output_data))
# Out:
# [ 4990.39345781] 6185.75468278
# 0.311526744279

# %%
plt.scatter(input_data, output_data)
plt.plot(input_data, regression3.predict(input_data), color='red', linewidth=3)

# %%
input_data = cars[['Cruise']]
output_data = cars['Price']
regression3 = linear_model.LinearRegression()
regression3.fit(input_data, output_data)

print(regression3.coef_, regression3.intercept_)
print(regression3.score(input_data, output_data))
# Out:
# [ 9862.32659956] 13921.8656669
# 0.185633009297

# %%
plt.scatter(input_data, output_data)
plt.plot(input_data, regression3.predict(input_data), color='red', linewidth=3)

# %%
input_data = cars[['Doors']]
output_data = cars['Price']
regression4 = linear_model.LinearRegression()
regression4.fit(input_data, output_data)

print(regression4.coef_, regression4.intercept_)
print(regression4.score(input_data, output_data))
# Out:
# [-1613.23238515] 27033.6002901
# 0.0192514665915

# %%
plt.scatter(input_data, output_data)
plt.plot(input_data, regression5.predict(input_data), color='red', linewidth=3)

# %%
input_data = cars[['Leather']]
output_data = cars['Price']
regression5 = linear_model.LinearRegression()
regression5.fit(input_data, output_data)

print(regression5.coef_, regression5.intercept_)
print(regression5.score(input_data, output_data))
# Out:
# [ 3473.4566033] 18828.7759276
# 0.0247108512641

# %%
plt.scatter(input_data, output_data)
plt.plot(input_data, regression5.predict(input_data), color='red', linewidth=3)

# %%
input_data = cars[['Sound']]
output_data = cars['Price']
regression6 = linear_model.LinearRegression()
regression6.fit(input_data, output_data)

print(regression6.coef_, regression6.intercept_)
print(regression6.score(input_data, output_data))
# Out:
# [-2631.40749469] 23130.1443794
# 0.0154623876242

# %%
plt.scatter(input_data, output_data)
plt.plot(input_data, regression6.predict(input_data), color='red', linewidth=3)

# %% [markdown]
# R^2
# 1. cylinder (0.323859037595)
# 2. liter (0.311526744279)
# 3. cruise (0.185633009297)
# 4. leather (0.0247108512641)
# 5. mileage (0.0204634473235)
# 6. doors (0.0192514665915)
# 7. sound (0.0154623876242)
#
# Adjusted R^2 = 1 -((1-R^2)(sample size - 1)/(sample size - vars - 1))
# Adjusted R^2 = 1 - ((1-R^2)(804-1)/(804-7-1))
#
#
# If we calculate the adjusted r^2 for each co
#
#
#
# Adjusted R^2
# 7. All Vars (
# 6. All Vars - sound
# 5. All Vars - doors
# 4. All Vars - mileage
# 3. All Vars - leather
# 2. All Vars - cruise
# 1. All Vars - liter

# %%
import itertools
possible_columns = ['Mileage', 'Cylinder', 'Liter', 'Cruise', 'Doors', 'Leather']

# %%
# 
combos = list(itertools.combinations(possible_columns, 2))
print(combos)
# Out:
# [('Mileage', 'Cylinder'), ('Mileage', 'Liter'), ('Mileage', 'Cruise'), ('Mileage', 'Doors'), ('Mileage', 'Leather'), ('Cylinder', 'Liter'), ('Cylinder', 'Cruise'), ('Cylinder', 'Doors'), ('Cylinder', 'Leather'), ('Liter', 'Cruise'), ('Liter', 'Doors'), ('Liter', 'Leather'), ('Cruise', 'Doors'), ('Cruise', 'Leather'), ('Doors', 'Leather')]
